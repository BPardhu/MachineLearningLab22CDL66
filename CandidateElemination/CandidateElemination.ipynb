# %%
import csv
a=[]
csvfile=open('1.csv','r') 
reader=csv.reader(csvfile) 
for row in reader:
    a.append(row) 
    print(row)
num_attributes=len(a[0])-1 
print("Initial hypothesis is ") 
S=['0']*num_attributes 
G=['?']*num_attributes 
print("The most specific : ",S) 
print("The most general : ",G)

for j in range(0,num_attributes): 
    S[j]=a[0][j]
print("The candidate algorithm \n") 
temp=[]

for i in range(0,len(a)): 
    if(a[i][num_attributes]=='Yes'):
        for j in range(0,num_attributes): 
            if(a[i][j]!=S[j]):
               S[j]='?'
        for j in range(0,num_attributes):
            for k in range(1,len(temp)):
                if temp[k][j]!='?' and temp[k][j]!=S[j]: 
                   del temp[k]
        print("For instance {0} the hypothesis is S{0}".format(i+1),S) 
        if(len(temp)==0):
            print("For instance {0} the hypothesis is G{0}".format(i+1),G) 
        else:
            print("For instance {0} the hypothesis is G{0}".format(i+1),temp)

    if(a[i][num_attributes]=='No'):
       for j in range(0,num_attributes): 
           if(S[j]!=a[i][j] and S[j]!='?'):
              G[j]=S[j]
              temp.append(G)
              G=['?']*num_attributes
       print("For instance {0} the hypothesis is S{0}".format(i+1),S) 
       print("For instance {0} the hypothesis is G{0}".format(i+1),temp)
# Out:
# ['Sunny', 'Warm', 'Normal', 'Strong', 'Warm', 'Same', 'Yes']
# ['Sunny', 'Warm', 'High', 'Strong', 'Warm', 'Same', 'Yes']
# ['Rainy', 'Cold', 'High', 'Strong', 'Warm', 'Change', 'No']
# ['Sunny', 'Warm', 'High', 'Strong', 'Cool', 'Change', 'Yes']
# ['Sunny', 'Warm', 'Normal', 'Strong', 'Warm', 'Same', 'No']
# ['Sunny', 'Warm', 'High', 'Strong', 'Warm', 'Same', 'Yes']
# ['Rainy', 'Cold', 'High', 'Strong', 'Warm', 'Change', 'No']
# ['Sunny', 'Warm', 'High', 'Strong', 'Cool', 'Change', 'Yes']
# ['Sunny', 'Warm', 'Normal', 'Strong', 'Warm', 'Same', 'No']
# ['Sunny', 'Warm', 'High', 'Strong', 'Warm', 'Same', 'Yes']
# ['Rainy', 'Cold', 'High', 'Strong', 'Warm', 'Change', 'No']
# ['Sunny', 'Warm', 'High', 'Strong', 'Cool', 'Change', 'Yes']
# ['Sunny', 'Warm', 'Normal', 'Strong', 'Warm', 'Same', 'No']
# ['Sunny', 'Warm', 'High', 'Strong', 'Warm', 'Same', 'Yes']
# ['Rainy', 'Cold', 'High', 'Strong', 'Warm', 'Change', 'No']
# ['Sunny', 'Warm', 'High', 'Strong', 'Cool', 'Change', 'Yes']
# ['Sunny', 'Warm', 'Normal', 'Strong', 'Warm', 'Same', 'No']
# ['Sunny', 'Warm', 'High', 'Strong', 'Warm', 'Same', 'Yes']
# ['Rainy', 'Cold', 'High', 'Strong', 'Warm', 'Change', 'No']
# ['Sunny', 'Warm', 'High', 'Strong', 'Cool', 'Change', 'No']
# Initial hypothesis is
# The most specific :  ['0', '0', '0', '0', '0', '0']
# The most general :  ['?', '?', '?', '?', '?', '?']
# The candidate algorithm
#
# For instance 1 the hypothesis is S1 ['Sunny', 'Warm', 'Normal', 'Strong', 'Warm', 'Same']
# For instance 1 the hypothesis is G1 ['?', '?', '?', '?', '?', '?']
# For instance 2 the hypothesis is S2 ['Sunny', 'Warm', '?', 'Strong', 'Warm', 'Same']
# For instance 2 the hypothesis is G2 ['?', '?', '?', '?', '?', '?']
# For instance 3 the hypothesis is S3 ['Sunny', 'Warm', '?', 'Strong', 'Warm', 'Same']
# For instance 3 the hypothesis is G3 [['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', 'Same']]
# For instance 4 the hypothesis is S4 ['Sunny', 'Warm', '?', 'Strong', '?', '?']
# For instance 4 the hypothesis is G4 [['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?']]
# For instance 5 the hypothesis is S5 ['Sunny', 'Warm', '?', 'Strong', '?', '?']
# For instance 5 the hypothesis is G5 [['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?']]
# For instance 6 the hypothesis is S6 ['Sunny', 'Warm', '?', 'Strong', '?', '?']
# For instance 6 the hypothesis is G6 [['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?']]
# For instance 7 the hypothesis is S7 ['Sunny', 'Warm', '?', 'Strong', '?', '?']
# For instance 7 the hypothesis is G7 [['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?'], ['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?']]
# For instance 8 the hypothesis is S8 ['Sunny', 'Warm', '?', 'Strong', '?', '?']
# For instance 8 the hypothesis is G8 [['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?'], ['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?']]
# For instance 9 the hypothesis is S9 ['Sunny', 'Warm', '?', 'Strong', '?', '?']
# For instance 9 the hypothesis is G9 [['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?'], ['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?']]
# For instance 10 the hypothesis is S10 ['Sunny', 'Warm', '?', 'Strong', '?', '?']
# For instance 10 the hypothesis is G10 [['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?'], ['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?']]
# For instance 11 the hypothesis is S11 ['Sunny', 'Warm', '?', 'Strong', '?', '?']
# For instance 11 the hypothesis is G11 [['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?'], ['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?'], ['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?']]
# For instance 12 the hypothesis is S12 ['Sunny', 'Warm', '?', 'Strong', '?', '?']
# For instance 12 the hypothesis is G12 [['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?'], ['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?'], ['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?']]
# For instance 13 the hypothesis is S13 ['Sunny', 'Warm', '?', 'Strong', '?', '?']
# For instance 13 the hypothesis is G13 [['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?'], ['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?'], ['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?']]
# For instance 14 the hypothesis is S14 ['Sunny', 'Warm', '?', 'Strong', '?', '?']
# For instance 14 the hypothesis is G14 [['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?'], ['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?'], ['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?']]
# For instance 15 the hypothesis is S15 ['Sunny', 'Warm', '?', 'Strong', '?', '?']
# For instance 15 the hypothesis is G15 [['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?'], ['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?'], ['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?'], ['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?']]
# For instance 16 the hypothesis is S16 ['Sunny', 'Warm', '?', 'Strong', '?', '?']
# For instance 16 the hypothesis is G16 [['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?'], ['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?'], ['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?'], ['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?']]
# For instance 17 the hypothesis is S17 ['Sunny', 'Warm', '?', 'Strong', '?', '?']
# For instance 17 the hypothesis is G17 [['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?'], ['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?'], ['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?'], ['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?']]
# For instance 18 the hypothesis is S18 ['Sunny', 'Warm', '?', 'Strong', '?', '?']
# For instance 18 the hypothesis is G18 [['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?'], ['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?'], ['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?'], ['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?']]
# For instance 19 the hypothesis is S19 ['Sunny', 'Warm', '?', 'Strong', '?', '?']
# For instance 19 the hypothesis is G19 [['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?'], ['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?'], ['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?'], ['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?'], ['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?']]
# For instance 20 the hypothesis is S20 ['Sunny', 'Warm', '?', 'Strong', '?', '?']
# For instance 20 the hypothesis is G20 [['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?'], ['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?'], ['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?'], ['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?'], ['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?']]
